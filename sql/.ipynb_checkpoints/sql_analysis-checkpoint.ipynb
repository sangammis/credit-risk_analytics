# %%
import pandas as pd
import sqlite3

# %%
df = pd.read_csv("../data/loan_customers_cleaned.csv")
df.head()
# Out:
#    customer_id  age  income  loan_amount  tenure employment_type  \
# 0            1   25   25000        50000      12        Contract
# 1            2   35   60000       200000      24        Salaried
# 2            3   40   45000       150000      36        Business
# 3            4   29   30000        80000      12        Contract
# 4            5   50   80000       300000      48        Salaried
#
#    credit_score    city  default_flag credit_score_group income_group  \
# 0           580   Delhi             1               Poor          Low
# 1           720  Mumbai             0               Good       Medium
# 2           650    Pune             0               Good       Medium
# 3           590   Delhi             1               Poor          Low
# 4           780  Mumbai             0          Excellent         High
#
#    risk_flag
# 0  High Risk
# 1   Low Risk
# 2   Low Risk
# 3  High Risk
# 4   Low Risk

# %%
# create sql database
conn = sqlite3.connect("Database/loan_customers_db")

# %%
# convert dataframe to sql
df.to_sql("loan_customers_table", conn, if_exists = "replace", index = False)
# Out:
# 200

# %%
pd.read_sql_query(
    " select * from loan_customers_table where credit_score > 600" , conn
)
# Out:
#      customer_id  age  income  loan_amount  tenure employment_type  \
# 0              2   35   60000       200000      24        Salaried
# 1              3   40   45000       150000      36        Business
# 2              5   50   80000       300000      48        Salaried
# 3              7   32   52000       120000      24        Salaried
# 4              8   45   75000       250000      36        Business
# ..           ...  ...     ...          ...     ...             ...
# 163          196   29   35000        96000      18        Contract
# 164          197   52   91000       360000      60        Salaried
# 165          198   37   58000       170000      24        Salaried
# 166          199   44   75000       265000      36        Business
# 167          200   30   36000        98000      18        Contract
#
#      credit_score       city  default_flag credit_score_group income_group  \
# 0             720     Mumbai             0               Good       Medium
# ...

# %%
# Defualt Rate
pd.read_sql_query(
    """ select count(*) as total_customers, 
    sum(default_flag) as total_defaults, 
    round(avg(default_flag)*100,2) as default_rate 
    from loan_customers_table """ 
    ,  conn)
# Out:
#    total_customers  total_defaults  default_rate
# 0              200              50          25.0

# %%
# Defualt Rate by employment type
pd.read_sql_query(
    """ select employment_type, count(*) as total_customers, 
    round(avg(default_flag)*100,2) as default_rate 
    from loan_customers_table 
    group by employment_type """ 
    ,  conn)
# Out:
#   employment_type  total_customers  default_rate
# 0        Business               65          0.00
# 1        Contract               60         83.33
# 2        Salaried               75          0.00

# %%
# credit score band analysis

query = """
select 
case
    when credit_score < 600 then 'Poor'
    when credit_score between 600 and 700 then 'Average'
    else 'Good'
end as score_band,
count(*) as customers, 
round(avg(default_flag)*100, 2) as default_rate
from loan_customers_table
group by score_band """

pd.read_sql_query(query, conn)
# Out:
#   score_band  customers  default_rate
# 0    Average         48          50.0
# 1       Good        126           0.0
# 2       Poor         26         100.0

# %%
# customers per city 
query = """
select city, 
count(*) as total_customers from loan_customers_table
group by city
"""
pd.read_sql_query(query, conn)
# Out:
#         city  total_customers
# 0  Bangalore               32
# 1    Chennai               25
# 2      Delhi               43
# 3  Hyderabad               30
# 4     Mumbai               37
# 5       Pune               33

# %%
# customers per city with good credit_score
query = """
select city, 
count(*) as total_customers from loan_customers_table
group by city
having credit_score > 700
"""
pd.read_sql_query(query, conn)
# Out:
#         city  total_customers
# 0    Chennai               25
# 1  Hyderabad               30
# 2     Mumbai               37
